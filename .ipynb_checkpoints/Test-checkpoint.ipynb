# %%
from pytube import YouTube, Search

# %%
yt = YouTube('https://www.youtube.com/watch?v=kffacxfA7G4')

caption = yt.captions.get_by_language_code('en')
print(caption.generate_str_captions())
# Out:
# <?xml version="1.0" encoding="utf-8" ?><timedtext format="3">
# <head>
# <ws id="1" ju="2"/>
# <wp id="30" ap="7" ah="50" av="100" rc="1" cc="10"/>
# <wp id="20" ap="7" ah="50" av="100" rc="1" cc="11"/>
# <wp id="2" ap="7" ah="50" av="100" rc="1" cc="12"/>
# <wp id="9" ap="7" ah="50" av="100" rc="1" cc="14"/>
# <wp id="4" ap="7" ah="50" av="100" rc="1" cc="15"/>
# <wp id="6" ap="7" ah="50" av="100" rc="1" cc="16"/>
# <wp id="10" ap="7" ah="50" av="100" rc="1" cc="18"/>
# <wp id="5" ap="7" ah="50" av="100" rc="1" cc="19"/>
# <wp id="13" ap="7" ah="50" av="100" rc="1" cc="20"/>
# <wp id="3" ap="7" ah="50" av="100" rc="1" cc="21"/>
# <wp id="19" ap="7" ah="50" av="100" rc="1" cc="22"/>
# <wp id="14" ap="7" ah="50" av="100" rc="1" cc="24"/>
# <wp id="15" ap="7" ah="50" av="100" rc="1" cc="25"/>
# <wp id="18" ap="7" ah="50" av="100" rc="1" cc="27"/>
# <wp id="23" ap="7" ah="50" av="100" rc="1" cc="32"/>
# <wp id="24" ap="7" ah="50" av="100" rc="1" cc="5"/>
# ...
